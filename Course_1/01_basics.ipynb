# %%
## Basic syntax rules in python
## Case sensitivity - python is case sensitive

name = "krish"
Name = "naik"

print(name)
print(Name)
# Out:
# krish
# naik

# %%
# Line continuation -> done using '\'

total = 1 + 2 + 3 + 4 + 5 + 6 + \
        7 + 8 + 9

print(total)
# Out:
# 45
